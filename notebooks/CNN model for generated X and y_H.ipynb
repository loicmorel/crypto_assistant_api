# %% [markdown]
# # Generate X and y for CNN model

# %%
# run only once.
import os
os.chdir("..")
# !pwd
# !pyenv version
# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/heather/code/loicmorel/crypto_assistant
# crypto_assistant (set by PYENV_VERSION environment variable)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyts.image import GramianAngularField
from mpl_toolkits.axes_grid1 import ImageGrid
from datetime import datetime
from datetime import timezone
from app.indicators import find_swings
from app.indicators import classify_swings

# %%
# run me...
def generate_gaf(data):
    gadf = GramianAngularField(method='difference', image_size=data.shape[0])
    img = gadf.fit_transform(pd.DataFrame(data).T)[0]
    return img

def generate_gaf_images_from_ohlc(data, params, idx):
    ## identify target
    target = False
    for t in params['target']:
        if data[:idx][t].iloc[-1]:
            target = t
    if not target:
        return np.nan

    ## slicing data from the bottom of the df (reverse the time) 
    ## to the top from the index provided by the lambda function
    data_slice = data[:idx][['o_ts', params['focus']]]
    img = []
    ret = params.copy()
    ret['target'] = target
    
    ## for 4x frequency to compose the gaf matrix
    for freq in params['freq']:
        data_ = data_slice.groupby(pd.Grouper(key='o_ts', freq=freq)).mean().reset_index()
        data_ = data_.dropna()
        data__ = data_[::-1].reset_index().drop(columns='index')
        data___ = data__[:params['depth']]
        if data___.shape[0] < params['depth']:
            return np.nan
        ret[f'start_time_{freq}'] = data___['o_ts'].iloc[0]
        ret[f'end_time_{freq}'] = data___['o_ts'].iloc[-1]
        img.append(generate_gaf(data___[params['focus']]))
    ret['img'] = np.array(img)
    return (ret)

def plot_gaf_image_matrix(img_np, target):
    image_matrix: tuple =(2, 2)
    fig = plt.figure(figsize=[img * 4 for img in image_matrix])
    plt.title(f'Target: {target}')
    grid = ImageGrid(fig,
                     111,
                     axes_pad=0,
                     nrows_ncols=image_matrix,
                     share_all=True,
                     )

    for ax, im in zip(grid, img_np):
        # Iterating over the grid returns the Axes.
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(im, cmap='rainbow', origin='lower')

# %% [markdown]
# # Data collection

# %%
from app.data_collection.datamgt import ohlcv_from_csv_to_df
file = 'data/ohlcv_ETHUSDT_1h_from_1502942400000_to_1651507200000.csv'
data = ohlcv_from_csv_to_df(file)
data
# Out:
#                      o_ts     Open     High      Low    Close       Volume  \
# 0     2017-08-17 04:00:00   301.13   302.57   298.00   301.61    125.66877
# 1     2017-08-17 05:00:00   301.61   303.28   300.00   303.10    377.67246
# 2     2017-08-17 06:00:00   302.40   304.44   301.90   302.68    303.86672
# 3     2017-08-17 07:00:00   302.68   307.96   302.60   307.96    754.74510
# 4     2017-08-17 08:00:00   307.95   309.97   307.00   308.62    150.75029
# ...                   ...      ...      ...      ...      ...          ...
# 41138 2022-05-02 12:00:00  2795.05  2811.47  2789.28  2795.57  17163.77510
# 41139 2022-05-02 13:00:00  2795.54  2845.10  2778.78  2829.25  64991.93710
# 41140 2022-05-02 14:00:00  2829.25  2852.53  2805.23  2828.00  46120.43640
# 41141 2022-05-02 15:00:00  2827.99  2835.49  2814.10  2827.68  24617.00230
# 41142 2022-05-02 16:00:00  2827.68  2833.66  2816.00  2832.76  11106.61120
#
#                                c_ts        o_date
# 0     2017-08-17 04:59:59.999000064  17395.166667
# 1     2017-08-17 05:59:59.999000064  17395.208333
# 2     2017-08-17 06:59:59.999000064  17395.250000
# 3     2017-08-17 07:59:59.999000064  17395.291667
# 4     2017-08-17 08:59:59.999000064  17395.333333
# ...                             ...           ...
# 41138 2022-05-02 12:59:59.999000064  19114.500000
# 41139 2022-05-02 13:59:59.999000064  19114.541667
# 41140 2022-05-02 14:59:59.999000064  19114.583333
# 41141 2022-05-02 15:59:59.999000064  19114.625000
# 41142 2022-05-02 16:59:59.999000064  19114.666667
#
# [41143 rows x 8 columns]

# %% [markdown]
# # Targets definition to the dataframe

# %%
# add HH, LL, LH, HL targets to the dataframe
target_df = classify_swings(find_swings(data))
# concat databases
data_c = pd.concat([data, target_df], axis="columns")
data_c.drop(columns=[
    'CSLS',
    'Support',
    'Resistance',
    'Strong_lows',
    'Strong_highs',
    'FSL',
    'FSH',
    'Highs',
    'Lows',
    'Last',
    'Trend',
    'o_date'
    ], inplace=True)
data_c
# Out:
#                      o_ts     Open     High      Low    Close       Volume  \
# 0     2017-08-17 04:00:00   301.13   302.57   298.00   301.61    125.66877
# 1     2017-08-17 05:00:00   301.61   303.28   300.00   303.10    377.67246
# 2     2017-08-17 06:00:00   302.40   304.44   301.90   302.68    303.86672
# 3     2017-08-17 07:00:00   302.68   307.96   302.60   307.96    754.74510
# 4     2017-08-17 08:00:00   307.95   309.97   307.00   308.62    150.75029
# ...                   ...      ...      ...      ...      ...          ...
# 41138 2022-05-02 12:00:00  2795.05  2811.47  2789.28  2795.57  17163.77510
# 41139 2022-05-02 13:00:00  2795.54  2845.10  2778.78  2829.25  64991.93710
# 41140 2022-05-02 14:00:00  2829.25  2852.53  2805.23  2828.00  46120.43640
# 41141 2022-05-02 15:00:00  2827.99  2835.49  2814.10  2827.68  24617.00230
# 41142 2022-05-02 16:00:00  2827.68  2833.66  2816.00  2832.76  11106.61120
#
#                                c_ts     LL     HL     HH     LH
# 0     2017-08-17 04:59:59.999000064  False  False  False  False
# 1     2017-08-17 05:59:59.999000064  False  False  False  False
# 2     2017-08-17 06:59:59.999000064  False  False  False  False
# 3     2017-08-17 07:59:59.999000064  False   True  False  False
# 4     2017-08-17 08:59:59.999000064  False  False  False  False
# ...                             ...    ...    ...    ...    ...
# 41138 2022-05-02 12:59:59.999000064  False  False  False  False
# 41139 2022-05-02 13:59:59.999000064  False  False  False  False
# 41140 2022-05-02 14:59:59.999000064   True  False  False  False
# 41141 2022-05-02 15:59:59.999000064  False  False  False  False
# 41142 2022-05-02 16:59:59.999000064  False  False  False  False
#
# [41143 rows x 11 columns]

# %% [markdown]
# # OHLC convertsion to GAF matrix

# %%
# generate img 2D array + params (freq, deepth) from dataframe and tag with target value

### ATTENTION: the freq[0] shall match with the freq of the raw data

encode_gaf_params = {
    # Depth of the timeframe, higher depth = bigger image.
    'depth': 40,
    # always 4x different frequency to constitute the 2x2 matrix of GAF images
    'freq': ['1h', '2h', '4h', '1d'],
    # focus on the Close price
    'focus': 'Close',
    # sensitiive to targets LL and HH
    'target': ['LL', 'HH']
}

data_c['gaf'] = data_c[::-1].apply(lambda r: generate_gaf_images_from_ohlc(data_c, encode_gaf_params, r.name+1), axis=1)
data_c = data_c.dropna().reset_index().drop(columns='index')
data_c
# Out:
#                     o_ts     Open     High      Low    Close       Volume  \
# 0    2017-09-25 14:00:00   288.69   297.12   288.01   295.72    423.58549
# 1    2017-09-25 18:00:00   292.69   294.18   291.03   293.53    250.43062
# 2    2017-09-26 08:00:00   293.00   293.90   289.56   292.06    182.65086
# 3    2017-09-26 22:00:00   289.45   290.99   287.87   289.45    192.03753
# 4    2017-09-27 04:00:00   291.02   292.88   291.01   291.54    232.29645
# ...                  ...      ...      ...      ...      ...          ...
# 4025 2022-04-30 20:00:00  2806.74  2807.86  2786.01  2790.03   9233.40660
# 4026 2022-05-01 02:00:00  2770.26  2780.62  2754.76  2758.16  16032.09270
# 4027 2022-05-01 19:00:00  2773.23  2777.62  2755.10  2765.39  20779.74640
# 4028 2022-05-02 08:00:00  2845.26  2855.86  2832.18  2838.83  13337.21820
# 4029 2022-05-02 14:00:00  2829.25  2852.53  2805.23  2828.00  46120.43640
#
#                               c_ts     LL     HL     HH     LH  \
# 0    2017-09-25 14:59:59.999000064   True  False  False  False
# 1    2017-09-25 18:59:59.999000064  False  False   True  False
# 2    2017-09-26 08:59:59.999000064   True  False  False  False
# 3    2017-09-26 22:59:59.999000064   True  False  False  False
# 4    2017-09-27 04:59:59.999000064   True  False  False  False
# ...                            ...    ...    ...    ...    ...
# 4025 2022-04-30 20:59:59.999000064   True  False  False  False
# 4026 2022-05-01 02:59:59.999000064   True  False  False  False
# 4027 2022-05-01 19:59:59.999000064  False  False   True  False
# 4028 2022-05-02 08:59:59.999000064  False  False   True  False
# 4029 2022-05-02 14:59:59.999000064   True  False  False  False
#
#                                                     gaf
# 0     {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# 1     {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# 2     {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# 3     {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# 4     {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# ...                                                 ...
# 4025  {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# 4026  {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# 4027  {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# 4028  {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
# 4029  {'depth': 40, 'freq': ['1h', '2h', '4h', '1d']...
#
# [4030 rows x 12 columns]

# %% [markdown]
# # display GAF matrix as images

# %%
# print 2 last gaf images
images = data_c[0:2].gaf
for img in images:
    plot_gaf_image_matrix(img['img'], img['target'])

# %% [markdown]
# # Generate X and y

# %%
images_meta = data_c.gaf
X = []
y = []
for img_meta in images_meta:
    X.append(img_meta['img'])
    if img_meta['target']=='HH':
        y.append(1)
    else:
        y.append(0)
X = np.array(X)
y = np.array(y)
X.shape, y.shape
# Out:
# ((4030, 4, 40, 40), (4030,))

# %%
y
# Out:
# array([0, 1, 0, ..., 1, 1, 0])

# %%
from sklearn.metrics import confusion_matrix

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import utils

from tensorflow.keras import optimizers, metrics

# %%
def get_model(params):
    model = models.Sequential()

    # Conv1
    model.add(layers.Conv2D(16, (2, 2), input_shape=(4,40, 40), padding='same', strides=(1, 1)))
    model.add(layers.Activation('sigmoid'))

    # Conv2
    model.add(layers.Conv2D(16, (2, 2), padding='same', strides=(1, 1)))
    model.add(layers.Activation('sigmoid'))

    # FC
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(params['classes'],activation='sigmoid'))
    model.summary()

    return model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from tensorflow.keras.callbacks import EarlyStopping

es=EarlyStopping(monitor='accuracy', patience=2)

# %%
def train_model(params):
    model = get_model(params)
    model.compile(loss='binary_crossentropy', optimizer=params['optimizer'], metrics=['accuracy'])
    hist = model.fit(x=X_train, y=y_train,
                     validation_split=0.2,
                     batch_size=params['batch_size'], epochs=params['epochs'], verbose=2,callbacks = [es])

    return (model, hist)

# %%
PARAMS = {}
PARAMS['model_name'] = './model/cnn_model_v1.h5'
PARAMS['classes'] = 1
PARAMS['lr'] = 0.01
PARAMS['epochs'] = 50
PARAMS['batch_size'] = 64
PARAMS['optimizer'] = optimizers.SGD(lr=PARAMS['lr'])

    # ---------------------------------------------------------

    # train cnn model
model, hist = train_model(PARAMS)
model.save(PARAMS['model_name'])


    
model.evaluate(X_test,y_test)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 4, 40, 16)         2576
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 40, 16)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 40, 16)         1040
# _________________________________________________________________
# activation_5 (Activation)    (None, 4, 40, 16)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2560)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               327808
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 331,553
# Trainable params: 331,553
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 34/34 - 0s - loss: 0.7152 - accuracy: 0.5148 - val_loss: 0.6876 - val_accuracy: 0.6333
# Epoch 2/50
# 34/34 - 0s - loss: 0.7019 - accuracy: 0.5139 - val_loss: 0.6983 - val_accuracy: 0.5130
# Epoch 3/50
# 34/34 - 0s - loss: 0.6891 - accuracy: 0.5343 - val_loss: 0.6814 - val_accuracy: 0.5907
# Epoch 4/50
# 34/34 - 0s - loss: 0.6863 - accuracy: 0.5407 - val_loss: 0.6797 - val_accuracy: 0.7074
# Epoch 5/50
# 34/34 - 0s - loss: 0.6828 - accuracy: 0.5588 - val_loss: 0.6917 - val_accuracy: 0.4870
# Epoch 6/50
# 34/34 - 0s - loss: 0.6808 - accuracy: 0.5616 - val_loss: 0.6739 - val_accuracy: 0.7315
# Epoch 7/50
# 34/34 - 0s - loss: 0.6769 - accuracy: 0.5796 - val_loss: 0.6749 - val_accuracy: 0.4944
# Epoch 8/50
# 34/34 - 0s - loss: 0.6753 - accuracy: 0.5722 - val_loss: 0.6666 - val_accuracy: 0.6796
# Epoch 9/50
# 34/34 - 0s - loss: 0.6732 - accuracy: 0.5815 - val_loss: 0.6601 - val_accuracy: 0.7296
# Epoch 10/50
# 34/34 - 0s - loss: 0.6682 - accuracy: 0.5991 - val_loss: 0.6546 - val_accuracy: 0.7333
# Epoch 11/50
# 34/34 - 0s - loss: 0.6610 - accuracy: 0.6157 - val_loss: 0.6493 - val_accuracy: 0.7093
# Epoch 12/50
# 34/34 - 0s - loss: 0.6536 - accuracy: 0.6412 - val_loss: 0.6557 - val_accuracy: 0.5296
# Epoch 13/50
# 34/34 - 0s - loss: 0.6509 - accuracy: 0.6431 - val_loss: 0.6379 - val_accuracy: 0.7481
# Epoch 14/50
# 34/34 - 0s - loss: 0.6459 - accuracy: 0.6495 - val_loss: 0.6341 - val_accuracy: 0.6481
# Epoch 15/50
# 34/34 - 0s - loss: 0.6319 - accuracy: 0.6741 - val_loss: 0.6315 - val_accuracy: 0.6333
# Epoch 16/50
# 34/34 - 0s - loss: 0.6199 - accuracy: 0.6963 - val_loss: 0.6049 - val_accuracy: 0.7352
# Epoch 17/50
# 34/34 - 0s - loss: 0.6102 - accuracy: 0.6981 - val_loss: 0.5937 - val_accuracy: 0.7537
# Epoch 18/50
# 34/34 - 0s - loss: 0.5985 - accuracy: 0.7194 - val_loss: 0.5779 - val_accuracy: 0.7574
# Epoch 19/50
# 34/34 - 0s - loss: 0.5855 - accuracy: 0.7204 - val_loss: 0.5589 - val_accuracy: 0.7833
# Epoch 20/50
# 34/34 - 0s - loss: 0.5645 - accuracy: 0.7394 - val_loss: 0.5472 - val_accuracy: 0.7722
# Epoch 21/50
# 34/34 - 0s - loss: 0.5599 - accuracy: 0.7310 - val_loss: 0.5270 - val_accuracy: 0.7704
# Epoch 22/50
# 34/34 - 0s - loss: 0.5398 - accuracy: 0.7468 - val_loss: 0.5085 - val_accuracy: 0.7833
# Epoch 23/50
# 34/34 - 0s - loss: 0.5268 - accuracy: 0.7620 - val_loss: 0.5283 - val_accuracy: 0.7537
# Epoch 24/50
# 34/34 - 0s - loss: 0.5262 - accuracy: 0.7500 - val_loss: 0.4711 - val_accuracy: 0.8037
# Epoch 25/50
# 34/34 - 0s - loss: 0.4983 - accuracy: 0.7745 - val_loss: 0.4558 - val_accuracy: 0.8130
# Epoch 26/50
# 34/34 - 0s - loss: 0.4756 - accuracy: 0.7838 - val_loss: 0.4370 - val_accuracy: 0.8111
# Epoch 27/50
# 34/34 - 0s - loss: 0.4564 - accuracy: 0.7963 - val_loss: 0.4271 - val_accuracy: 0.8185
# Epoch 28/50
# 34/34 - 0s - loss: 0.4514 - accuracy: 0.7981 - val_loss: 0.4134 - val_accuracy: 0.8278
# Epoch 29/50
# 34/34 - 0s - loss: 0.4305 - accuracy: 0.8167 - val_loss: 0.3915 - val_accuracy: 0.8426
# Epoch 30/50
# 34/34 - 0s - loss: 0.4206 - accuracy: 0.8153 - val_loss: 0.3724 - val_accuracy: 0.8500
# Epoch 31/50
# 34/34 - 0s - loss: 0.4160 - accuracy: 0.8213 - val_loss: 0.3626 - val_accuracy: 0.8611
# Epoch 32/50
# 34/34 - 0s - loss: 0.3722 - accuracy: 0.8569 - val_loss: 0.3501 - val_accuracy: 0.8648
# Epoch 33/50
# 34/34 - 0s - loss: 0.3714 - accuracy: 0.8477 - val_loss: 0.3446 - val_accuracy: 0.8630
# Epoch 34/50
# 34/34 - 0s - loss: 0.3589 - accuracy: 0.8505 - val_loss: 0.3193 - val_accuracy: 0.8741
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3349 - accuracy: 0.8692
# [0.334902286529541, 0.8691729307174683]

# %%
model.predict_classes(X_test)
# Out:
# array([[0],
#        [1],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]], dtype=int32)
